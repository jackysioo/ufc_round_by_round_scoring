# %%
import UFC_data_scraping
# Out:
#  27%|██████████████████████▎                                                            | 7/26 [00:13<00:36,  1.93s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-2740f0516319> in <module>
# ----> 1 import UFC_data_scraping
#
# ~\ufc_round_by_round_scoring\UFC_data_scraping.py in <module>
#      67
#      68 # + colab={"base_uri": "https://localhost:8080/", "height": 216} id="AkCCSiuUa4lu" outputId="de1fcb58-1d27-4f12-8dd7-5644ddfb2ec6"
# ---> 69 ALL_FIGHTERS = get_all_fighters()
#      70 ALL_FIGHTERS.head()
#      71
#
# ~\ufc_round_by_round_scoring\UFC_data_scraping.py in get_all_fighters()
#      59     for c in tqdm(ascii_lowercase):
#      60         all_fighters_url = f"http://ufcstats.com/statistics/fighters?char={c}&page=all"
# ---> 61         all_fighters_table = pd.read_html(all_fighters_url)[0]
# ...
